# %%
import pandas as pd
pd.set_option("display.max_rows", 2000)

data = pd.read_csv('pddata.csv')

# %%
data[['id','date','title','type']]
# Out:
#         id        date                                              title type
# 0        0    2020/6/6    关于对中国U19国家男子足球队球员陶强龙、刘祝润、彭号、任丽昊、韩东、何龙海违规违纪的处罚决定  txt
# 1        1   2019/11/5                     关于对广州富力足球俱乐部队官员斯托伊科维奇违规违纪的处罚决定  txt
# 2        2   2019/11/5                     关于对天津泰达足球俱乐部U19队球员赵研博违规违纪的处罚决定  txt
# 3        3  2019/10/24                        关于对淄博蹴鞠足球俱乐部队球员张丰羽违规违纪的处罚决定  txt
# 4        4  2019/10/24                       关于对四川优必选足球俱乐部队球员耿晓顺违规违纪的处罚决定  txt
# 5        5  2019/10/24                        关于对成都兴城足球俱乐部队球员胡明天违规违纪的处罚决定  txt
# 6        6  2019/10/24                        关于对大连千兆足球俱乐部队球员董志远违规违纪的处罚决定  txt
# 7        7  2019/10/24                        关于对大连千兆足球俱乐部队官员刘宏毅违规违纪的处罚决定  txt
# 8        8  2019/10/24                         关于对河北精英女子足球队官员侯智敏违规违纪的处罚决定  txt
# 9        9  2019/10/24                     关于对上海申鑫足球俱乐部U19队球员苗祥涛违规违纪的处罚决定  txt
# 10      10   2019/9/27                             中国足协关于天津天海俱乐部球员张鹭的处罚决定  txt
# ...
